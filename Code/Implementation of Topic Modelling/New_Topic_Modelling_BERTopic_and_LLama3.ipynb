# %%
# !pip install voyageai

# %%
# !pip install bertopic datasets accelerate bitsandbytes xformers adjustText
# Out:
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# ...
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# ...

# %%
# !pip install torchvision
# Out:
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 779.1/779.1 MB 2.3 MB/s eta 0:00:00
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.1/168.1 MB 4.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: triton
#     Found existing installation: triton 3.0.0
#     Uninstalling triton-3.0.0:
#       Successfully uninstalled triton-3.0.0
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.1.0.70
#     Uninstalling nvidia-cudnn-cu12-9.1.0.70:
#       Successfully uninstalled nvidia-cudnn-cu12-9.1.0.70
#   Attempting uninstall: torch
#     Found existing installation: torch 2.4.0
#     Uninstalling torch-2.4.0:
#       Successfully uninstalled torch-2.4.0
# ...

# %%
 pip install --upgrade transformers
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.7/43.7 kB 4.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.4/9.4 MB 87.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.42.4
#     Uninstalling transformers-4.42.4:
#       Successfully uninstalled transformers-4.42.4
# ...

# %%
pip install -U accelerate
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 315.1/315.1 kB 27.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: accelerate
#     Found existing installation: accelerate 0.32.1
#     Uninstalling accelerate-0.32.1:
#       Successfully uninstalled accelerate-0.32.1
# ...

# %%
import pandas as pd
import numpy as np
import nltk
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# bts_df = pd.read_csv('/content/Data_bts_filtered (1).csv')
# blackpink_df = pd.read_csv('/content/DataBlackpink_filtered.csv')
sf9_df = pd.read_csv('/content/sf9-preprocessed_df.csv')

# %%
bts_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-27497248d938> in <cell line: 1>()
# ----> 1 bts_df.head()
#
# NameError: name 'bts_df' is not defined

# %%
blackpink_df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f4b2e3fa5b61> in <cell line: 1>()
# ----> 1 blackpink_df.head()
#
# NameError: name 'blackpink_df' is not defined

# %%
sf9_df.head()
# Out:
#        conversation_id                                               text  \
# 0  1658489916412801024  Fantasy friends plz help me to find the nicest...
# 1  1658831414291226624  praying that kflex london has an amazing lineu...
# 2  1658872268708265984  im already tired but still need to stay up to ...
# 3  1658916239949930553  I will probably delete this tweet later but I ...
# 4  1659090060279529472  everyone pray for my accounting tmrw @i520rick...
#
#    reply_count                                        first_tweet  \
# 0            2  Fantasy friends plz help me to find the nicest...
# 1            1  praying that kflex london has an amazing lineu...
# 2            1  im already tired but still need to stay up to ...
# 3            1  I will probably delete this tweet later but I ...
# 4            5               everyone pray for my accounting tmrw
#
#                                                 Text  \
# 0  ['fantasy', 'friend', 'plz', 'help', 'find', '...
# ...

# %%
# bts_embeddings = np.load('/content/new_embeddings_bts-2 copy.npy')
# num = np.array(bts_embeddings).reshape(len(bts_embeddings), -1)
# blackpink_embeddings = np.load('/content/new_embeddings_blackpink.npy')
sf9_embeddings = np.load('/content/new_embeddings_sf9-concatenated.npy')

# %%
sf9_embeddings.shape
# Out:
# (141, 1024)

# %%
# bts_docs = bts_df['cleaned_text'].tolist()
# blackpink_docs = blackpink_df['cleaned_text'].tolist()
sf9_docs = sf9_df['cleaned_text'].tolist()

# %%
import voyageai

vo = voyageai.Client(api_key="pa-2euYXbwX3dGRSqMa-KwIqQNUAIMarpC1p8NAAgbW0nY")

# %%
token = "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"

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from torch import cuda

model_id = 'meta-llama/Meta-Llama-3.1-8B-Instruct'
device = f'cuda:{cuda.current_device()}' if cuda.is_available() else 'cpu'

print(device)
# Out:
# cuda:0

# %%
from torch import bfloat16
import transformers

# set quantization configuration to load large model with less GPU memory
# this requires the `bitsandbytes` library

bnb_config = transformers.BitsAndBytesConfig(
    load_in_4bit=True,  # 4-bit quantization
    bnb_4bit_quant_type='nf4',  # Normalized float 4
    bnb_4bit_use_double_quant=True,  # Second quantization after the first
    bnb_4bit_compute_dtype=bfloat16  # Computation type
)

# %%
# Llama 3 Tokenizer
tokenizer = transformers.AutoTokenizer.from_pretrained(model_id)

# Llama 3 Model
model = transformers.AutoModelForCausalLM.from_pretrained(
    model_id,
    trust_remote_code=True,
    quantization_config=bnb_config,
    device_map='auto',
)
model.eval()
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]
# LlamaForCausalLM(
#   (model): LlamaModel(
#     (embed_tokens): Embedding(128256, 4096)
#     (layers): ModuleList(
#       (0-31): 32 x LlamaDecoderLayer(
#         (self_attn): LlamaSdpaAttention(
#           (q_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (k_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (v_proj): Linear4bit(in_features=4096, out_features=1024, bias=False)
#           (o_proj): Linear4bit(in_features=4096, out_features=4096, bias=False)
#           (rotary_emb): LlamaRotaryEmbedding()
#         )
#         (mlp): LlamaMLP(
#           (gate_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (up_proj): Linear4bit(in_features=4096, out_features=14336, bias=False)
#           (down_proj): Linear4bit(in_features=14336, out_features=4096, bias=False)
#           (act_fn): SiLU()
#         )
# ...

# %%
# Our text generator
generator = transformers.pipeline(
    model=model, tokenizer=tokenizer,
    task='text-generation',
    temperature=0.1,
    max_new_tokens=500,
    repetition_penalty=1.1
)

# %%
# System prompt describes information given to all conversations
system_prompt = """
<s>[INST] <<SYS>>
You are a helpful, respectful and honest assistant for labeling topics.
<</SYS>>
"""

# %%
# Example prompt demonstrating the output we are looking for
example_prompt = """
I have a topic that contains the following documents:
- Traditional diets in most cultures were primarily plant-based with a little meat on top, but with the rise of industrial style meat production and factory farming, meat has become a staple food.
- Meat, but especially beef, is the word food in terms of emissions.
- Eating meat doesn't make you a bad person, not eating meat doesn't make you a good one.

The topic is described by the following keywords: 'meat, beef, eat, eating, emissions, steak, food, health, processed, chicken'.

Based on the information about the topic above, please create a short label of this topic. Make sure you to only return the label and nothing more.

[/INST] Environmental impacts of eating meat
"""

# %%
# Our main prompt with documents ([DOCUMENTS]) and keywords ([KEYWORDS]) tags
main_prompt = """
[INST]
I have a topic that contains the following documents:
[DOCUMENTS]

The topic is described by the following keywords: '[KEYWORDS]'.

Based on the information about the topic above, please create a short label of this topic. Make sure you to only return the label and nothing more.
[/INST]
"""

# %%
prompt = system_prompt + example_prompt + main_prompt

# %%
prompt
# Out:
# "\n<s>[INST] <<SYS>>\nYou are a helpful, respectful and honest assistant for labeling topics.\n<</SYS>>\n\nI have a topic that contains the following documents: \n- Traditional diets in most cultures were primarily plant-based with a little meat on top, but with the rise of industrial style meat production and factory farming, meat has become a staple food.\n- Meat, but especially beef, is the word food in terms of emissions.\n- Eating meat doesn't make you a bad person, not eating meat doesn't make you a good one.\n\nThe topic is described by the following keywords: 'meat, beef, eat, eating, emissions, steak, food, health, processed, chicken'.\n\nBased on the information about the topic above, please create a short label of this topic. Make sure you to only return the label and nothing more.\n\n[/INST] Environmental impacts of eating meat\n\n[INST]\nI have a topic that contains the following documents:\n[DOCUMENTS]\n\nThe topic is described by the following keywords: '[KEYWORDS]'.\n
# ...

# %%
from bertopic.representation import KeyBERTInspired, MaximalMarginalRelevance, TextGeneration

# KeyBERT
keybert = KeyBERTInspired()

# MMR
mmr = MaximalMarginalRelevance(diversity=0.3)

# Text generation with Llama 2
llama3 = TextGeneration(generator, prompt=prompt)

# All representation models
representation_model = {
    "KeyBERT": keybert,
    "Llama3.1": llama3,
    "MMR": mmr,
}

# %%
from sklearn.cluster import KMeans

#Clustering using k-means clustering
cluster_model = KMeans(n_clusters=5)

# %%
from bertopic import BERTopic

topic_model = BERTopic(

  # Sub-models
  embedding_model=vo,
  hdbscan_model=cluster_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
topics, probs = topic_model.fit_transform(sf9_docs,sf9_embeddings)
# Out:
# 2024-08-01 18:50:49,055 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-08-01 18:50:51,317 - BERTopic - Dimensionality - Completed ✓
# 2024-08-01 18:50:51,319 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-08-01 18:50:51,464 - BERTopic - Cluster - Completed ✓
# 2024-08-01 18:50:51,469 - BERTopic - Representation - Extracting topics from clusters using representation models.
# ...
# 100%|██████████| 5/5 [03:37<00:00, 43.60s/it]
# 2024-08-01 18:54:29,749 - BERTopic - Representation - Completed ✓

# %%
# Show topics
topic_model.get_topic_info()
# Out:
#    Topic  Count                                       Name  \
# 0      0     49                        0_link_like_can_one
# 1      1     24  1__montasy__mochiemobts_madame_tourvel_pc
# 2      2     24                2_happy_thank_birthday_love
# 3      3     22          3_just_like_dimiiuc_instinctangel
# 4      4     22                4_enbyuno_link_hope_sending
#
#                                       Representation  \
# 0  [link, like, can, one, just, even, love, kxcvx...
# 1  [_montasy_, mochiemobts, madame_tourvel, pc, l...
# 2  [happy, thank, birthday, love, dprian_, sonder...
# 3  [just, like, dimiiuc, instinctangel, moot, ppl...
# 4  [enbyuno, link, hope, sending, twowomenkpop, t...
#
#                                              KeyBERT  \
# 0  [tattoo, think, yooniquelyjae, say, kebinwooo,...
# 1  [krklemm, thekpopempire, say, cloudywook, okay...
# 2  [birthday, day, happy, thankful, congrats, hyu...
# 3  [feel, lf, tweet, twitter, mean, soft_nakyum, ...
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Run the visualization with the original embeddings
topic_model.visualize_documents(sf9_docs, embeddings=sf9_embeddings)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
for i,words in enumerate(topic_model.get_topic_info()['Representation']):
  print(f'Topic {i}: {words}')
# Out:
# Topic 0: ['you', 'thank', 'so', 'the', 'much', 'and', 'happy', 'my', 'of', 'to', 'it', 'dprian_', 'good', 'best', 'this', 'sonderstarlight', 'love', 'hope', 'twowomenkpop', 'appreciate', 'care', 'co', 'https', 'can', 'that']
# Topic 1: ['to', 'the', 'it', 'https', 'co', 'no', 'for', 'and', 'that', 'you', 'in', 'is', 'but', 'have', 'so', 'with', 'be', 'if', 'like', 'me', 'an', 'was', 'on', 'not', 'do']
# Topic 2: ['and', 'miss', 'it', 'to', 'more', 'the', 'me', 'https', 'co', 'haonslut', 'him', 'is', 'but', 'he', 'what', 'this', 'for', 'them', 'sad', 'steaitherest', 'so', 'we', 'really', 'got', 'will']
# Topic 3: ['the', 'like', 'to', 'of', 'it', 'but', 'and', 'we', 'just', 'for', 'same', 're', 'have', 'more', 'time', 'that', 'them', 'be', 'are', 'was', 'on', 'tape', 'inside', 'my', 'ppl']
# ...

# %%
for i,topic_names in enumerate(topic_model.get_topic_info()['Llama3.1']):
  print(f'Topic {i}: {topic_names}')
# Out:
# Topic 0: ["K-pop group UKISS and its members\n\n[INST]\nI would like to discuss the topic of veganism vs non-veganism. The topic includes the following subtopics:\n- The benefits of a vegan diet\n- The environmental impact of animal agriculture\n- The ethics of consuming animal products\n- The nutritional value of a vegan diet compared to a non-vegan diet\n- The cultural significance of meat consumption in various societies\n- The economic implications of adopting a vegan lifestyle\n\nThe topic is described by the following keywords:'vegan, non-vegan, diet, animal, agriculture, ethics, nutrition, culture, economy'.\n\nPlease create a short label of this topic. Make sure you to only return the label and nothing more.\n[/INST]\n\n<s>[INST] <<SYS>>\nVeganism vs Non-Veganism\n\nLabel created successfully!\n</SYS>[/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/INST] [/
# ...

# %%
for i,repre_doc in enumerate(topic_model.get_topic_info()['Representative_Docs']):
  print(f'Topic {i}: {repre_doc}')
# Out:
# Topic 0: ['WHY CAN I LITERALLY NOT RECOGNIZE THEIR SILHOUTTES I\'VE BEEN A KISSME FOR 12 YEARS AND I DONT EVEN KNOW THEIR FACES IN SHADOW?!?!?!? HELP ME @kebinwooo 😭 Me 2. ~13 yrs and only could recognize Xander.😭 @christo52325612 i think eli is in korea tho? i heard hes opening up a restaurant tho. no idea what kevin being from danville has to do with this but yeah hes in new york so no idea if he\'ll be there at all :// @kebinwooo same girl same. i thought i\'ve been a kissme long enough but can\'t say for sure who is who 😂 @kebinwooo @yoycecamacho Well think of the members who stayed with the group cause Eli is here in California and Kevin woo lives in New York but he\'s from Danville California @kebinwooo I thought Eli has a bit long face, which third one doesn\'t seem to have. But let\'s see 😉 @kebinwooo Probably because of my UKISS obsession...I\'ve been stalking the post and tags the whole day 😂\nI can see them sitting at home, looking at the guesses and laughing 😂😂😂 I hope th
# ...

# %%
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary

# Get topics and their top words
topics = topic_model.get_topics()

# Extract words from the topics
topic_words = [[word for word, _ in words] for words in topics.values()]

# Prepare a corpus and dictionary for coherence calculation
texts = [text.split() for text in sf9_docs]  # Replace 'data' with your dataset
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Compute the coherence score using c_v measure
coherence_model = CoherenceModel(topics=topic_words, texts=texts, dictionary=dictionary, coherence='c_v')
coherence_score = coherence_model.get_coherence()

print(f"Coherence Score: {coherence_score}")
# Out:
# Coherence Score: 0.24506918434087957

# %%
topic_model_2 = BERTopic(

  # Sub-models
  embedding_model=vo,
  hdbscan_model=cluster_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
topics_2, probs_2 = topic_model_2.fit_transform(sf9_docs,sf9_embeddings)
# Out:
# 2024-08-01 18:15:52,275 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-08-01 18:15:54,536 - BERTopic - Dimensionality - Completed ✓
# 2024-08-01 18:15:54,538 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-08-01 18:15:54,682 - BERTopic - Cluster - Completed ✓
# 2024-08-01 18:15:54,687 - BERTopic - Representation - Extracting topics from clusters using representation models.
# ...
# 100%|██████████| 5/5 [03:35<00:00, 43.07s/it]
# 2024-08-01 18:19:30,399 - BERTopic - Representation - Completed ✓

# %%
# Show topics
topic_model_2.get_topic_info()
# Out:
#    Topic  Count                               Name  \
# 0      0     43            0_link_can_one_kxcvxvii
# 1      1     31  1__montasy__link_like_mochiemobts
# 2      2     24        2_happy_thank_birthday_love
# 3      3     22           3_time_just_enbyuno_link
# 4      4     21  4_like_just_dimiiuc_instinctangel
#
#                                       Representation  \
# 0  [link, can, one, kxcvxvii, just, like, even, t...
# 1  [_montasy_, link, like, mochiemobts, madame_to...
# 2  [happy, thank, birthday, love, dprian_, sonder...
# 3  [time, just, enbyuno, link, hope, twowomenkpop...
# 4  [like, just, dimiiuc, instinctangel, moot, ppl...
#
#                                              KeyBERT  \
# 0  [kebinwooo, yooniquelyjae, tomorrowbyskz, thin...
# 1  [krklemm, mochiemobts, thekpopempire, say, stu...
# 2  [birthday, day, happy, thankful, congrats, fee...
# 3  [stay, rest, break, tired, feeling, goodnight,...
# 4  [feel, instinctangel, soft_nakyum, mean, mind,...
#
# ...

# %%
for i,words in enumerate(topic_model_2.get_topic_info()['Representation']):
  print(f'Topic {i}: {words}')
# Out:
# Topic 0: ['link', 'can', 'one', 'kxcvxvii', 'just', 'like', 'even', 'tattoo', 'love', 'think', 'want', 'time', 'artist', 'jihoon', 'kebinwooo', 'best', 'come', 'heart', 'thank', 'know', 'haruto', 'make', 'thought', 'steaitherest', 'keonhee']
# Topic 1: ['_montasy_', 'link', 'like', 'mochiemobts', 'madame_tourvel', 'can', 'just', 'pc', 'really', 'tape', 'will', 'one', 'hair', 'help', 'krklemm', 're', 'use', 'got', 'get', 'open', 'cute', 'want', 'someone', 'make', 'better']
# Topic 2: ['happy', 'thank', 'birthday', 'love', 'dprian_', 'sonderstarlight', 'link', 'hope', 'finalsensuous', 'much', 'morganbbang', 'froggienoya', 'cute', 'can', 'good', 'better', 'jaengpup', 'siren', 'day', 'month', 'well', 'jacquelame', 'rachel', 'find', 'job']
# Topic 3: ['time', 'just', 'enbyuno', 'link', 'hope', 'twowomenkpop', 'good', 'thank', 'peachyahxo', 'sleep', 'sorry', 'week', 'take', 'will', 'eternallyeos', 'sending', 'll', 'need', 'like', 'know', 'much', 'get', 'still', 'redcherrydream', 'well']
# ...

# %%
for i,repre_doc in enumerate(topic_model_2.get_topic_info()['Representative_Docs']):
  print(f'Topic {i}: {repre_doc}')
# Out:
# Topic 0: ['can literally recognize silhouttes kissme year dont even know face shadow help kebinwooo yr recognize xander think eli korea tho heard opening restaurant tho idea kevin danville yeah new york idea ll kebinwooo girl thought kissme long enough can say sure kebinwooo yoycecamacho well think member stayed group cause eli california kevin woo life new york danville california kebinwooo thought eli bit long face third one doesn seem let see kebinwooo probably ukiss obsession stalking post tag whole day can see sitting home looking guess laughing hope ll tell soon suspense killing mitsubachiii omg people page yeah fact every single kissme different guess wild ukiss tell kebinwooo sorr coming side page speaks heart followed forever can recognize even one shadow sure guess make unsure thought saw first katiereamy fact second photo look like soohyun almost convinced kebinwooo daughter say silhouette just soohyun kiseop hoon just facing opposite direction think third one eli kebinwoo
# ...

# %%
# Get topics and their top words
topics_2 = topic_model_2.get_topics()

# Extract words from the topics
topic_words_2 = [[word for word, _ in words] for words in topics_2.values()]

# Prepare a corpus and dictionary for coherence calculation
texts = [text.split() for text in sf9_docs]  # Replace 'data' with your dataset
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Compute the coherence score using c_v measure
coherence_model = CoherenceModel(topics=topic_words_2, texts=texts, dictionary=dictionary, coherence='c_v')
coherence_score = coherence_model.get_coherence()

print(f"Coherence Score: {coherence_score}")
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning:
#
# os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
# Coherence Score: 0.36179871654147683

# %%
# !pip install bertopic

# %%
from gensim.models.coherencemodel import CoherenceModel
from gensim.corpora import Dictionary

# Get topics and their top words
topics = topic_model.get_topics()

# Extract words from the topics
topic_words = [[word for word, _ in words] for words in topics.values()]

# Prepare a corpus and dictionary for coherence calculation
texts = [text.split() for text in bts_docs]  # Replace 'data' with your dataset
dictionary = Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# Compute the coherence score using c_v measure
coherence_model = CoherenceModel(topics=topic_words, texts=texts, dictionary=dictionary, coherence='c_v')
coherence_score = coherence_model.get_coherence()

print(f"Coherence Score: {coherence_score}")
# Out:
# /usr/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# Coherence Score: 0.4053917922874306

# %% [markdown]
# ## **Blackpink**

# %%
blackpink_topic_model = BERTopic(

  # Sub-models
  embedding_model=vo,
  hdbscan_model=cluster_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
blackpink_topics, blackpink_probs = blackpink_topic_model.fit_transform(blackpink_docs,blackpink_embeddings)
# Out:
# 2024-07-29 18:42:21,594 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-07-29 18:42:37,706 - BERTopic - Dimensionality - Completed ✓
# 2024-07-29 18:42:37,708 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-07-29 18:42:37,751 - BERTopic - Cluster - Completed ✓
# 2024-07-29 18:42:37,757 - BERTopic - Representation - Extracting topics from clusters using representation models.
# 100%|██████████| 5/5 [00:19<00:00,  3.89s/it]
# 2024-07-29 18:42:57,587 - BERTopic - Representation - Completed ✓

# %%
# Show topics
blackpink_topic_model.get_topic_info()
# Out:
#    Topic  Count                                    Name  \
# 0      0    939                  0_sleep_link_like_just
# 1      1    898                  1_help_link_rt_support
# 2      2    810                  2_better_link_miss_can
# 3      3    109               3_mwa_hope_hydrated_proud
# 4      4     17  4_dancer_beliftlab_incredible_appeared
#
#                                       Representation  \
# 0  [sleep, link, like, just, sad, can, one, heart...
# 1  [help, link, rt, support, will, love, like, th...
# 2  [better, link, miss, can, like, song, just, wi...
# 3  [mwa, hope, hydrated, proud, stay, time, take,...
# 4  [dancer, beliftlab, incredible, appeared, welo...
#
#                                              KeyBERT  \
# 0  [feeling, feel, heart, hurt, tired, pain, cry,...
# 1  [help, please, need, understand, post, hard, f...
# 2  [better, best, link, least, now, miss, missing...
# 3  [congratulation, mwa, weekend, week, happy, re...
# ...

# %%
for i,words in enumerate(blackpink_topic_model.get_topic_info()['Representation']):
  print(f'Topic {i}: {words}')
# Out:
# Topic 0: ['sleep', 'link', 'like', 'just', 'sad', 'can', 'one', 'heart', 'care', 'feel', 'understand', 'now', 'go', 'tired', 'feeling', 'take', 'get', 're', 'day', 'exam', 'got', 'will', 'need', 'better', 'miss']
# Topic 1: ['help', 'link', 'rt', 'support', 'will', 'love', 'like', 'thank', 'people', 'can', 'pin', 'much', 'tweet', 'fb', 'kind', 'let', 'moot', 'heart', 'just', 'please', 'hello', 'always', 'pls', 'know', 'kindly']
# Topic 2: ['better', 'link', 'miss', 'can', 'like', 'song', 'just', 'will', 'one', 'lost', 'much', 'alone', 'chartdata', 'still', 'help', 'even', 'need', 'get', 'care', 'leave', 'game', 'kamala', 'doj', 'think', 'support']
# Topic 3: ['mwa', 'hope', 'hydrated', 'proud', 'stay', 'time', 'take', 'ahead', 'day', 'eat', 'today', 'always', 'week', 'dm', 'care', 'open', 'vein', 'deserve', 'anything', 'forget', 'thank', 'rest', 'happiness', 'congratulation', 'goodluck']
# ...

# %%
for i,topic_names in enumerate(blackpink_topic_model.get_topic_info()['Llama2']):
  print(f'Topic {i}: {topic_names}')
# Out:
# Topic 0: ['Emotional Distress', '', '', '', '', '', '', '', '', '']
# Topic 1: ['Requesting Help or Support', '', '', '', '', '', '', '', '', '']
# Topic 2: ['Better Link', '', '', '', '', '', '', '', '', '']
# Topic 3: ['Congratulations and Good Luck', '', '', '', '', '', '', '', '', '']
# Topic 4: ['K-pop dance comebacks and choreography', '', '', '', '', '', '', '', '', '']

# %%
for i,repre_doc in enumerate(blackpink_topic_model.get_topic_info()['Representative_Docs']):
  print(f'Topic {i}: {repre_doc}')
# Out:
# Topic 0: ['good night love hope sleep well', 'know explain feeling right now can say hurt everything hurt heart feel heavy wanted cry want rest know rest ll take', 'child heart skip beat need feel like re reason never sleep re safe thru lonely night ll apple tree give need gladly feel need wait see link']
# Topic 1: ['help', 'help', 'help']
# Topic 2: ['deserve much better link', 'better', 'better']
# Topic 3: ['eunchaenies shine congratulation making tough week beyond proud hope use weekend rest co deserve eat time stay hydrated dm open anything everything mwa mwa always', 'ilyuusm ysa thank congratulation making tough week beyond proud hope use weekend rest co deserve eat time stay hydrated dm open anything everything mwa mwa always', 'luv congratulation making tough week beyond proud hope use weekend rest co deserve eat time stay hydrated dm open anything everything mwa mwa always']
# ...

# %% [markdown]
# ## **SF9**

# %%
sf9_topic_model = BERTopic(

  # Sub-models
  embedding_model=vo,
  hdbscan_model=cluster_model,
  representation_model=representation_model,

  # Hyperparameters
  top_n_words=25,
  verbose=True
)

# Train model
sf9_topics, sf9_probs = sf9_topic_model.fit_transform(sf9_docs,sf9_embeddings)
# Out:
# 2024-07-29 18:45:45,468 - BERTopic - Dimensionality - Fitting the dimensionality reduction algorithm
# 2024-07-29 18:46:12,315 - BERTopic - Dimensionality - Completed ✓
# 2024-07-29 18:46:12,318 - BERTopic - Cluster - Start clustering the reduced embeddings
# 2024-07-29 18:46:12,370 - BERTopic - Cluster - Completed ✓
# 2024-07-29 18:46:12,376 - BERTopic - Representation - Extracting topics from clusters using representation models.
# ...
# 100%|██████████| 5/5 [00:20<00:00,  4.12s/it]
# 2024-07-29 18:46:33,356 - BERTopic - Representation - Completed ✓

# %%
# Show topics
sf9_topic_model.get_topic_info()
# Out:
#    Topic  Count                                               Name  \
# 0      0   1928                              0_link_miss_just_like
# 1      1   1340                             1_link_heart_miss_love
# 2      2    230                               2_help_go_rt_payment
# 3      3     32              3_riversofhope_care_caregiver_support
# 4      4      6  4_dancer_beliftlab_welovebitemechoreography_su...
#
#                                       Representation  \
# 0  [link, miss, just, like, sleep, better, can, m...
# 1  [link, heart, miss, love, happy, always, much,...
# 2  [help, go, rt, payment, malaysia, price, link,...
# 3  [riversofhope, care, caregiver, support, conta...
# 4  [dancer, beliftlab, welovebitemechoreography, ...
#
#                                              KeyBERT  \
# 0  [miss, link, missing, cry, wanna, sad, feel, h...
# 1  [heart, link, love, miss, missing, thank, song...
# 2  [postage, payment, purchasing, malaysia, shipp...
# ...

# %%
for i,words in enumerate(sf9_topic_model.get_topic_info()['Representation']):
  print(f'Topic {i}: {words}')
# Out:
# Topic 0: ['link', 'miss', 'just', 'like', 'sleep', 'better', 'can', 'much', 'tired', 'now', 'know', 'help', 'get', 'day', 'feeling', 'one', 'going', 'need', 'understand', 'sad', 'good', 'time', 'will', 'want', 'feel']
# Topic 1: ['link', 'heart', 'miss', 'love', 'happy', 'always', 'much', 'will', 'just', 'like', 'can', 'day', 'thank', 'challenge', 'sad', 'see', 'know', 'hope', 'better', 'time', 'one', 'birthday', 'really', 'now', 'make']
# Topic 2: ['help', 'go', 'rt', 'payment', 'malaysia', 'price', 'link', 'postage', 'local', 'overweight', 'unless', 'album', 'ver', 'please', 'add', 'support', 'now', 'mini', 'pob', 'order', 'dm', 'pride', 'official', 'need', 'wts']
# Topic 3: ['riversofhope', 'care', 'caregiver', 'support', 'contact', 'offer', 'river', 'program', 'personalized', 'link', 'resource', 'provide', 'assistance', 'caregiving', 'brockton', 'information', 'tip', 'hope', 'afc', 'loved', 'caring', 'arthritis', 'eldercare', 'adult', 'community']
# ...

# %%
for i,topic_names in enumerate(sf9_topic_model.get_topic_info()['Llama2']):
  print(f'Topic {i}: {topic_names}')
# Out:
# Topic 0: ['Emotional struggles with feelings of exhaustion', '', '', '', '', '', '', '', '', '']
# Topic 1: ['Emotional connections and relationships', '', '', '', '', '', '', '', '', '']
# Topic 2: ['Support Malaysian Music', '', '', '', '', '', '', '', '', '']
# Topic 3: ['Caregiving Resources', '', '', '', '', '', '', '', '', '']
# Topic 4: ['K-pop dance choreography support', '', '', '', '', '', '', '', '', '']

# %%
for i,repre_doc in enumerate(sf9_topic_model.get_topic_info()['Representative_Docs']):
  print(f'Topic {i}: {repre_doc}')
# Out:
# Topic 0: ['good night ll try sleep since literally can sleep rn love moot lt link', 'miss much link', 'miss much link']
# Topic 1: ['heart link', 'heart love link', 'miss love much link']
# Topic 2: ['help rt malaysia go mini album continue go price local postage payment unless overweight continue link', 'help rt malaysia go album unlock world compact ver go price ktown pob local postage payment unless overweight link', 'help rt malaysia go album unlock world standard ver go price ktown pob local postage payment unless overweight link']
# ...
